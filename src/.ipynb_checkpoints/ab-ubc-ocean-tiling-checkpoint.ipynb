# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
import cv2
import tqdm
"""
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
"""
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# "\nfor dirname, _, filenames in os.walk('/kaggle/input'):\n    for filename in filenames:\n        print(os.path.join(dirname, filename))\n"

# %%
imagesFolder = "D:\\own_projects\\Ovarian_cancer\\train_thumbnails"
images = os.listdir(imagesFolder)

# %%
width = []
height = []

for img in tqdm.tqdm(images):
    img = cv2.imread(os.path.join(imagesFolder, img))
    height.append(img.shape[0])
    width.append(img.shape[1])
# Out:
# 100%|██████████| 513/513 [00:50<00:00, 10.18it/s]

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (10,10))
plt.scatter(np.arange(len(width)), width)
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (10,10))
plt.scatter(np.arange(len(height)), height)
plt.show()

# %%
from statistics import mean
mean(width)

# %%
import cv2
import numpy as np
import os

def create_image_tiles(input_path, output_folder, tile_size=(256, 256), overlap=0):
    """
    Create image tiles from large images.

    Parameters:
    - input_path: Path to the directory containing large images.
    - output_path: Path to the directory where tiles will be saved.
    - tile_size: Tuple representing the size of each tile (height, width).
    - overlap: Number of pixels for tile overlap. Use 0 for no overlap.

    Note: This example assumes that input images are in a single directory.
    """

    

    # Iterate through each image in the input directory
    #for filename in os.listdir(input_path):
        #if filename.endswith(('.jpg', '.jpeg', '.png')):
            # Read the image
    filename = input_path.split('\\')[-1]
    filenameWithoutExt = filename.split('.')[0]
    print(filenameWithoutExt)
    output_path = os.path.join(output_folder, filenameWithoutExt)
    # Create output directory if it doesn't exist
    os.makedirs(output_path, exist_ok=True)
    
    img_path = os.path.join(input_path)#, filename) # for inpur path we have the whole image path
    img = cv2.imread(input_path)

    # Get image dimensions
    height, width, _ = img.shape

    # Calculate the number of tiles in each dimension
    num_tiles_height = int(np.ceil(height / (tile_size[0] - overlap)))
    num_tiles_width = int(np.ceil(width / (tile_size[1] - overlap)))

    # Iterate through each tile position
    for i in range(num_tiles_height):
        for j in range(num_tiles_width):
            # Calculate tile coordinates
            start_y = i * (tile_size[0] - overlap)
            end_y = min(start_y + tile_size[0], height)

            start_x = j * (tile_size[1] - overlap)
            end_x = min(start_x + tile_size[1], width)

            # Extract the tile from the image
            tile = img[start_y:end_y, start_x:end_x]

            # Save the tile to the output directory
            tile_filename = f"{os.path.splitext(filename)[0]}_tile_{i}_{j}.png"
            tile_path = os.path.join(output_path, tile_filename)
            cv2.imwrite(tile_path, tile)

# %%
INPUT_FOLDER = "D:\\own_projects\\Ovarian_cancer\\train_thumbnails"
OUTPUT_FOLDER = "D:\\own_projects\\Ovarian_cancer\\train_tiled_thumbnail_images"

for img in tqdm.tqdm(images):
    create_image_tiles(os.path.join(INPUT_FOLDER, img), OUTPUT_FOLDER, tile_size=(256, 256), overlap=10)
# Out:
#   0%|          | 0/513 [00:00<?, ?it/s]
# 10077_thumbnail
#   0%|          | 1/513 [00:00<02:00,  4.24it/s]
# 10143_thumbnail
#   0%|          | 2/513 [00:00<02:50,  3.00it/s]
# 1020_thumbnail
#   1%|          | 3/513 [00:00<02:40,  3.18it/s]
# 10246_thumbnail
#   1%|          | 4/513 [00:01<02:37,  3.23it/s]
# 10252_thumbnail
#   1%|          | 5/513 [00:01<02:35,  3.26it/s]
# 10469_thumbnail
#   1%|          | 6/513 [00:01<02:24,  3.51it/s]
# 10548_thumbnail
# 10642_thumbnail
#   2%|▏         | 8/513 [00:02<01:41,  4.98it/s]
# 10800_thumbnail
#   2%|▏         | 9/513 [00:02<01:50,  4.54it/s]
# 1080_thumbnail
#   2%|▏         | 10/513 [00:02<01:53,  4.43it/s]
# 10896_thumbnail
#   2%|▏         | 11/513 [00:02<02:00,  4.17it/s]
# 1101_thumbnail
#   3%|▎         | 13/513 [00:03<01:38,  5.09it/s]
# 11263_thumbnail
# 11417_thumbnail
#   3%|▎         | 15/513 [00:03<01:48,  4.60it/s]
# 11431_thumbnail
# 11557_thumbnail
#   3%|▎         | 17/513 [00:04<01:45,  4.70it/s]
# 11559_thumbnail
# 12159_thumbnail
#   4%|▎         | 19/513 [00:04<01:28,  5.56it/s]
# 12222_thumbnail
# 12244_thumbnail
#   4%|▍         | 21/513 [00:04<01:24,  5.81it/s]
# 12442_thumbnail
# 12522_thumbnail
#   4%|▍         | 23/513 [00:05<01:29,  5.45it/s]
# 1252_thumbnail
# 1289_thumbnail
#   5%|▍         | 24/513 [00:05<01:27,  5.62it/s]
# 12902_thumbnail
#   5%|▌         | 26/513 [00:05<01:30,  5.37it/s]
# 1295_thumbnail
# 13364_thumbnail
#   5%|▌         | 27/513 [00:06<01:53,  4.28it/s]
# 13387_thumbnail
#   5%|▌         | 28/513 [00:06<02:03,  3.91it/s]
# 13526_thumbnail
#   6%|▌         | 30/513 [00:06<01:43,  4.67it/s]
# 13987_thumbnail
# 14039_thumbnail
#   6%|▌         | 31/513 [00:06<01:32,  5.24it/s]
# 14051_thumbnail
# 14127_thumbnail
#   7%|▋         | 34/513 [00:07<01:09,  6.87it/s]
# 14312_thumbnail
# 14401_thumbnail
#   7%|▋         | 35/513 [00:07<01:15,  6.32it/s]
# 14424_thumbnail
#   7%|▋         | 36/513 [00:07<01:24,  5.64it/s]
# 14532_thumbnail
#   7%|▋         | 37/513 [00:07<01:44,  4.55it/s]
# 14542_thumbnail
# 14617_thumbnail
#   8%|▊         | 40/513 [00:08<01:24,  5.62it/s]
# 15139_thumbnail
# 15188_thumbnail
#   8%|▊         | 41/513 [00:08<01:41,  4.65it/s]
# 15209_thumbnail
#   8%|▊         | 43/513 [00:09<01:33,  5.04it/s]
# 15221_thumbnail
# 15231_thumbnail
#   9%|▉         | 45/513 [00:09<01:13,  6.38it/s]
# 15293_thumbnail
# 15470_thumbnail
# 15486_thumbnail
#   9%|▉         | 47/513 [00:09<01:04,  7.27it/s]
# 15583_thumbnail
#   9%|▉         | 48/513 [00:09<01:14,  6.26it/s]
# 15671_thumbnail
#  10%|▉         | 49/513 [00:10<01:26,  5.38it/s]
# 15742_thumbnail
#  10%|▉         | 51/513 [00:10<01:32,  5.00it/s]
# 15871_thumbnail
#  10%|█         | 52/513 [00:10<01:19,  5.80it/s]
# 15912_thumbnail
# 16042_thumbnail
# 16064_thumbnail
#  11%|█         | 55/513 [00:11<01:19,  5.76it/s]
# 16209_thumbnail
# 16325_thumbnail
#  12%|█▏        | 59/513 [00:11<00:50,  8.97it/s]
# 16494_thumbnail
# 1660_thumbnail
# 1666_thumbnail
# 16876_thumbnail
# 16986_thumbnail
#  12%|█▏        | 62/513 [00:12<01:18,  5.72it/s]
# 17067_thumbnail
# 17174_thumbnail
#  12%|█▏        | 63/513 [00:12<01:35,  4.70it/s]
# 17291_thumbnail
#  12%|█▏        | 64/513 [00:12<01:46,  4.20it/s]
# 17365_thumbnail
#  13%|█▎        | 66/513 [00:13<01:37,  4.59it/s]
# 17416_thumbnail
# 17487_thumbnail
#  13%|█▎        | 68/513 [00:13<01:33,  4.74it/s]
# 17738_thumbnail
# 1774_thumbnail
#  13%|█▎        | 69/513 [00:14<01:43,  4.31it/s]
# 17854_thumbnail
#  14%|█▍        | 71/513 [00:14<01:37,  4.53it/s]
# 18014_thumbnail
# 18138_thumbnail
#  14%|█▍        | 73/513 [00:14<01:28,  4.96it/s]
# 18196_thumbnail
# 18547_thumbnail
#  14%|█▍        | 74/513 [00:15<01:38,  4.47it/s]
# 18568_thumbnail
#  15%|█▍        | 75/513 [00:15<02:09,  3.39it/s]
# 18607_thumbnail
#  15%|█▍        | 76/513 [00:15<02:15,  3.23it/s]
# 18810_thumbnail
#  15%|█▌        | 77/513 [00:16<02:08,  3.39it/s]
# 18813_thumbnail
#  15%|█▌        | 79/513 [00:16<01:51,  3.88it/s]
# 18896_thumbnail
# 18914_thumbnail
# 18981_thumbnail
#  16%|█▌        | 81/513 [00:17<01:56,  3.70it/s]
# 19030_thumbnail
#  16%|█▌        | 83/513 [00:17<01:54,  3.77it/s]
# 19157_thumbnail
# 19255_thumbnail
#  16%|█▋        | 84/513 [00:18<01:45,  4.05it/s]
# 1925_thumbnail
#  17%|█▋        | 86/513 [00:18<01:31,  4.64it/s]
# 1943_thumbnail
# 19512_thumbnail
#  17%|█▋        | 87/513 [00:18<01:18,  5.45it/s]
# 1952_thumbnail
#  17%|█▋        | 88/513 [00:18<01:39,  4.27it/s]
# 19569_thumbnail
#  17%|█▋        | 89/513 [00:19<01:38,  4.29it/s]
# 20205_thumbnail
#  18%|█▊        | 90/513 [00:19<01:36,  4.37it/s]
# 20312_thumbnail
#  18%|█▊        | 91/513 [00:19<01:35,  4.40it/s]
# 20316_thumbnail
#  18%|█▊        | 92/513 [00:19<01:37,  4.31it/s]
# 20329_thumbnail
#  18%|█▊        | 93/513 [00:20<01:39,  4.20it/s]
# 20463_thumbnail
#  19%|█▊        | 96/513 [00:20<01:16,  5.45it/s]
# 20670_thumbnail
# 20858_thumbnail
# 20882_thumbnail
#  19%|█▉        | 97/513 [00:20<01:20,  5.16it/s]
# 2097_thumbnail
#  19%|█▉        | 99/513 [00:21<01:13,  5.63it/s]
# 21232_thumbnail
# 21260_thumbnail
# 21303_thumbnail
#  29%|██▉       | 148/513 [00:31<01:11,  5.08it/s]
# 27739_thumbnail
# 27747_thumbnail
#  29%|██▉       | 150/513 [00:31<01:03,  5.67it/s]
# 27851_thumbnail
# 27950_thumbnail
# 28028_thumbnail
#  30%|██▉       | 152/513 [00:31<01:08,  5.26it/s]
# 28066_thumbnail
#  30%|███       | 154/513 [00:32<01:03,  5.66it/s]
# 28121_thumbnail
# 281_thumbnail
# 28393_thumbnail
#  31%|███       | 157/513 [00:32<00:56,  6.26it/s]
# 28519_thumbnail
# 28562_thumbnail
#  31%|███       | 159/513 [00:32<00:52,  6.72it/s]
# 28603_thumbnail
# 286_thumbnail
#  31%|███       | 160/513 [00:33<01:02,  5.61it/s]
# 28736_thumbnail
#  31%|███▏      | 161/513 [00:33<01:14,  4.72it/s]
# 28821_thumbnail
#  32%|███▏      | 162/513 [00:33<01:17,  4.52it/s]
# 28922_thumbnail
#  32%|███▏      | 164/513 [00:33<01:05,  5.32it/s]
# 2906_thumbnail
# 29147_thumbnail
#  32%|███▏      | 165/513 [00:34<01:05,  5.29it/s]
# 29200_thumbnail
#  33%|███▎      | 167/513 [00:34<01:05,  5.25it/s]
# 29240_thumbnail
# 29331_thumbnail
#  33%|███▎      | 168/513 [00:34<00:59,  5.81it/s]
# 29615_thumbnail
#  33%|███▎      | 169/513 [00:35<01:12,  4.75it/s]
# 29888_thumbnail
#  34%|███▎      | 172/513 [00:35<00:57,  5.89it/s]
# 29904_thumbnail
# 29915_thumbnail
# 30203_thumbnail
#  34%|███▎      | 173/513 [00:35<01:02,  5.44it/s]
# 30272_thumbnail
#  34%|███▍      | 175/513 [00:36<01:09,  4.85it/s]
# 30369_thumbnail
#  35%|███▍      | 177/513 [00:36<00:51,  6.59it/s]
# 30508_thumbnail
# 30515_thumbnail
# 30539_thumbnail
#  35%|███▍      | 179/513 [00:36<00:46,  7.16it/s]
# 3055_thumbnail
# 30712_thumbnail
#  35%|███▌      | 182/513 [00:37<00:43,  7.59it/s]
# 30738_thumbnail
# 30792_thumbnail
# 30794_thumbnail
#  36%|███▌      | 183/513 [00:37<00:53,  6.18it/s]
# 3084_thumbnail
#  36%|███▌      | 185/513 [00:37<00:55,  5.87it/s]
# 30868_thumbnail
# 3092_thumbnail
#  36%|███▋      | 186/513 [00:37<00:53,  6.15it/s]
# 30986_thumbnail
#  37%|███▋      | 188/513 [00:38<00:52,  6.20it/s]
# 3098_thumbnail
# 31033_thumbnail
#  37%|███▋      | 189/513 [00:38<00:55,  5.82it/s]
# 31297_thumbnail
#  37%|███▋      | 190/513 [00:38<01:01,  5.26it/s]
# 31300_thumbnail
#  37%|███▋      | 192/513 [00:39<01:00,  5.34it/s]
# 31333_thumbnail
# 31383_thumbnail
#  38%|███▊      | 193/513 [00:39<01:09,  4.58it/s]
# 31473_thumbnail
# 31793_thumbnail
#  38%|███▊      | 195/513 [00:39<01:04,  4.92it/s]
# 3191_thumbnail
# 58974_thumbnail
# 59002_thumbnail
#  84%|████████▎ | 429/513 [01:29<00:19,  4.22it/s]
# 59031_thumbnail
#  84%|████████▍ | 430/513 [01:29<00:19,  4.33it/s]
# 59383_thumbnail
#  84%|████████▍ | 432/513 [01:30<00:18,  4.32it/s]
# 59515_thumbnail
# 59589_thumbnail
#  84%|████████▍ | 433/513 [01:30<00:18,  4.34it/s]
# 5970_thumbnail
#  85%|████████▍ | 435/513 [01:31<00:17,  4.40it/s]
# 59760_thumbnail
# 59900_thumbnail
#  85%|████████▌ | 437/513 [01:31<00:12,  6.05it/s]
# 5992_thumbnail
# 60058_thumbnail
#  86%|████████▌ | 439/513 [01:31<00:11,  6.38it/s]
# 60287_thumbnail
# 60685_thumbnail
# 60928_thumbnail
#  86%|████████▌ | 441/513 [01:31<00:08,  8.41it/s]
# 60936_thumbnail
#  86%|████████▌ | 442/513 [01:32<00:11,  5.93it/s]
# 60988_thumbnail
#  87%|████████▋ | 444/513 [01:32<00:12,  5.48it/s]
# 61033_thumbnail
# 61089_thumbnail
#  87%|████████▋ | 446/513 [01:32<00:11,  5.76it/s]
# 61100_thumbnail
# 61280_thumbnail
#  87%|████████▋ | 447/513 [01:32<00:11,  5.60it/s]
# 61320_thumbnail
#  87%|████████▋ | 448/513 [01:33<00:15,  4.21it/s]
# 6140_thumbnail
#  88%|████████▊ | 449/513 [01:33<00:16,  3.99it/s]
# 61424_thumbnail
#  88%|████████▊ | 450/513 [01:33<00:15,  4.05it/s]
# 61493_thumbnail
#  88%|████████▊ | 451/513 [01:34<00:17,  3.53it/s]
# 61689_thumbnail
# 6175_thumbnail
#  88%|████████▊ | 454/513 [01:34<00:11,  5.04it/s]
# 61823_thumbnail
# 61852_thumbnail
#  89%|████████▊ | 455/513 [01:35<00:14,  4.07it/s]
# 61961_thumbnail
#  89%|████████▉ | 457/513 [01:35<00:13,  4.14it/s]
# 62476_thumbnail
# 62641_thumbnail
#  89%|████████▉ | 458/513 [01:36<00:23,  2.37it/s]
# 6281_thumbnail
#  90%|████████▉ | 460/513 [01:36<00:17,  3.09it/s]
# 62828_thumbnail
# 63015_thumbnail
#  90%|████████▉ | 461/513 [01:37<00:15,  3.40it/s]
# 63121_thumbnail
#  90%|█████████ | 462/513 [01:37<00:14,  3.56it/s]
# 63165_thumbnail
#  90%|█████████ | 463/513 [01:37<00:13,  3.58it/s]
# 63289_thumbnail
#  90%|█████████ | 464/513 [01:37<00:14,  3.31it/s]
# 63298_thumbnail
#  91%|█████████ | 466/513 [01:38<00:11,  4.05it/s]
# 63367_thumbnail
# 63429_thumbnail
#  91%|█████████ | 467/513 [01:38<00:09,  4.74it/s]
# 6359_thumbnail
#  91%|█████████▏| 469/513 [01:39<00:10,  4.25it/s]
# 6363_thumbnail
# 63836_thumbnail
#  92%|█████████▏| 470/513 [01:39<00:12,  3.37it/s]
# 63897_thumbnail
#  92%|█████████▏| 471/513 [01:40<00:19,  2.12it/s]
# 63941_thumbnail
#  92%|█████████▏| 472/513 [01:40<00:16,  2.48it/s]
# 64111_thumbnail
#  92%|█████████▏| 474/513 [01:41<00:11,  3.52it/s]
# 64188_thumbnail
# 6449_thumbnail
#  93%|█████████▎| 475/513 [01:41<00:09,  4.03it/s]
# 64629_thumbnail
#  93%|█████████▎| 476/513 [01:41<00:09,  3.80it/s]
# 64771_thumbnail
#  93%|█████████▎| 478/513 [01:42<00:10,  3.30it/s]
# 64824_thumbnail
#  93%|█████████▎| 479/513 [01:42<00:09,  3.62it/s]
# 64950_thumbnail
# 65022_thumbnail
#  94%|█████████▎| 480/513 [01:42<00:10,  3.01it/s]
# 65094_thumbnail
#  94%|█████████▍| 482/513 [01:43<00:09,  3.26it/s]
# 65300_thumbnail
# 65371_thumbnail
#  94%|█████████▍| 483/513 [01:44<00:11,  2.69it/s]
# 65533_thumbnail
#  94%|█████████▍| 484/513 [01:44<00:11,  2.57it/s]
# 6558_thumbnail
#  95%|█████████▍| 485/513 [01:44<00:11,  2.47it/s]
# 6582_thumbnail
#  95%|█████████▍| 486/513 [01:45<00:10,  2.62it/s]
# 66_thumbnail
#  95%|█████████▍| 487/513 [01:45<00:10,  2.39it/s]
# 6793_thumbnail
#  95%|█████████▌| 488/513 [01:46<00:09,  2.72it/s]
# 6843_thumbnail
#  95%|█████████▌| 489/513 [01:46<00:07,  3.04it/s]
# 6898_thumbnail
#  96%|█████████▌| 490/513 [01:46<00:08,  2.57it/s]
# 6951_thumbnail
#  96%|█████████▌| 492/513 [01:47<00:06,  3.14it/s]
# 706_thumbnail
# 7204_thumbnail
#  96%|█████████▌| 493/513 [01:47<00:07,  2.53it/s]
# 7329_thumbnail
#  96%|█████████▋| 494/513 [01:48<00:09,  2.07it/s]
# 7482_thumbnail
#  97%|█████████▋| 496/513 [01:49<00:06,  2.75it/s]
# 7490_thumbnail
#  97%|█████████▋| 498/513 [01:49<00:03,  4.20it/s]
# 7955_thumbnail
# 8130_thumbnail
#  97%|█████████▋| 499/513 [01:49<00:03,  4.46it/s]
# 8213_thumbnail
# 8240_thumbnail
#  98%|█████████▊| 501/513 [01:50<00:02,  4.15it/s]
# 8279_thumbnail
# 8531_thumbnail
#  98%|█████████▊| 502/513 [01:50<00:02,  4.37it/s]
# 8713_thumbnail
#  98%|█████████▊| 504/513 [01:50<00:02,  3.95it/s]
# 8805_thumbnail
#  98%|█████████▊| 505/513 [01:50<00:01,  4.79it/s]
# 8985_thumbnail
# 9154_thumbnail
#  99%|█████████▉| 507/513 [01:51<00:01,  4.59it/s]
# 9183_thumbnail
# 9254_thumbnail
#  99%|█████████▉| 509/513 [01:51<00:00,  5.11it/s]
# 9341_thumbnail
# 9509_thumbnail
#  99%|█████████▉| 510/513 [01:52<00:00,  3.86it/s]
# 9658_thumbnail
# 100%|█████████▉| 512/513 [01:52<00:00,  4.38it/s]
# 9697_thumbnail
# 970_thumbnail
# 100%|██████████| 513/513 [01:52<00:00,  4.55it/s]
